# %%
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
aa = np.load('/content/drive/My Drive/Newdata/ordered_by_patient/115_30_116_116_1.npy')

# %%
print(aa.shape)
print(aa[100].shape)
volume = aa[0]
tmp = tf.convert_to_tensor(
    volume, dtype=None, dtype_hint=None, name=None)
print(tmp.shape)

tmp = tf.linalg.normalize(
    tmp, ord='euclidean', axis=None, name=None)

print(tmp.shape)

# %%
x = np.arange(volume.shape[0])[:, None, None]
y = np.arange(volume.shape[1])[None, :, None]
z = np.arange(volume.shape[2])[None, None, :]
x, y, z = np.broadcast_arrays(x, y, z)

# %%
c = np.tile(volume.ravel()[:, None], [1, 3])
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(x.ravel(),
           y.ravel(),
           z.ravel(), zdir='z', c= 'blue')
